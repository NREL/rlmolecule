# %%
import os
import sys
import numpy as np
# import psycopg2
import sqlalchemy
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(
    context='paper',
    font_scale=8/8.8,
#     context="talk",
    style='ticks',
    color_codes=True,
    rc={'legend.frameon': False})

plt.rcParams['svg.fonttype'] = 'none'

# %matplotlib inline

# %%
print(np.__version__)
print(pd.__version__)
# Out:
# 1.21.0
# 1.1.4

# %%
os.chdir('../')

# %%
print(os.getcwd())
sys.path.append('../../')
import rlmolecule
from rlmolecule.sql.run_config import RunConfig
from rlmolecule.sql import Base, Session
from rlmolecule.sql.tables import GameStore, RewardStore, StateStore
# Out:
# /home/jlaw/projects/arpa-e/crystals/rlmolecule/examples/crystal_volume

# %%
# connect to the db
# config_file = "config/config_eagle.yaml"
config_file = "/projects/rlmolecule/jlaw/crystal_vol/opt_cvol_mcts100_debug/run.yaml"
run_config = RunConfig(config_file)
engine = run_config.start_engine()
Session.configure(bind=engine)
session = Session()

# %%
def load_games_played(session, run_id):
#     print("Loading games")
    df = pd.read_sql(session.query(GameStore).filter_by(run_id=run_id).statement, session.bind)

    df['time_hours'] = (df.time - df.time.min()).apply(lambda x: x.total_seconds() / 3600)
    df = df.sort_values('time_hours')
    df_games = df
    df_games.reset_index(drop=True, inplace=True)
#     print(df_games.tail(3))
    return df_games


def load_rewards(session, run_id):
#     print("Loading rewards")
    df = pd.read_sql(session.query(RewardStore).filter_by(run_id=run_id).statement, session.bind)
    # df['time_hours'] = (df.time - df.time.min()).apply(lambda x: x.total_seconds() / 3600)
    df = df.sort_values('reward', ascending=False)
    df_rew = df
#     print(df_rew.tail(3))
    return df_rew


def load_states(session, run_id):
#     print("Loading rewards")
    df = pd.read_sql(session.query(StateStore).filter_by(run_id=run_id).statement, session.bind)
    return df

def get_state_for_rew(digest, df_state):
    return df_state[df_state['digest'] == digest]


# def write_best_crystals():
#     df_rew = load_rewards

# %%
def plot_reward_train_curves(df, log, out_dir, title=""):
    fig, axs = plt.subplots(sharex=True, nrows=2, figsize=(3, 2.75), dpi=150)
    axs[0].plot(df.time_hours, df.raw_reward, '.', ms=.75, label='games')
    axs[0].plot(df.time_hours, df.raw_reward.rolling(250, min_periods=50).quantile(.75), label='$r_{75}$')

    axs[1].plot(log.time_hours, log.policy_wrapper_loss, label='value loss')
    axs[1].plot(log.time_hours, log.policy_wrapper_1_loss, label='prior loss')

    axs[0].legend(loc='upper right', ncol=2, borderpad=0, borderaxespad=0,
                bbox_to_anchor=(1.1, 1.2), markerscale=10)
    axs[1].legend(
        loc='upper right', ncol=2,
        borderpad=0, borderaxespad=0.1,
        bbox_to_anchor=(1.1, 1.2))

    # axs[0].set_ylim([0, 250])
#     axs[0].set_ylim([0, 1.0])
    #axs[1].set_ylim([0, .7])
    #axs[1].set_xlim([-.01, 4])
    axs[0].set_ylabel('Reward')
    axs[1].set_ylabel('Policy Training')
    axs[1].set_xlabel('Time (hours)')

    plt.tight_layout()
    sns.despine(offset=5, trim=True)
    plt.suptitle(title, y=1.0)

    out_file = f"{out_dir}/training-and-reward.svg"
    print(out_file)
    os.makedirs(os.path.dirname(out_file), exist_ok=True)
    plt.savefig(out_file, bbox_inches="tight")
    plt.savefig(out_file.replace('.svg','.pdf'), bbox_inches="tight")
    plt.savefig(out_file.replace('.svg','.png'), bbox_inches="tight")
    plt.show()
    plt.close()

# %% [markdown]
# # Compare Experiment Results

# %%
exp_name = "crystal_vol"
run_id = run_config.run_id
print(run_id)
# Out:
# opt_cvol_mcts100_debug

# %%
def main_results(run_id, session):
    working_dir = f"/projects/rlmolecule/jlaw/{exp_name}/{run_id}"
    # load the games played
    df_games = load_games_played(session, run_id)
    print(df_games.head())

    log_file = f"{working_dir}/policy_checkpoints/log.csv"
    print(f"Reading {log_file}")
    log = pd.read_csv(log_file)
    log['time'] = pd.to_datetime(log.time)
    log['time'] = pd.to_datetime(log.time)
    log['time_hours'] = (log.time - df_games.time.min()).apply(lambda x: x.total_seconds() / 3600)
#     print(log.tail(3))

    # now plot the results
    out_dir = f"{working_dir}/viz"
    plot_reward_train_curves(df_games, log, out_dir, title=run_id)

    # and write POSCAR files for the best molecules
    df_rew = load_rewards(session, run_id)
    print(df_rew.head())
    return df_rew

# %%
df_rew = main_results(run_id, session)
# Out:
#                                      id                  run_id  \
# 0  979c1665-1239-4e14-9712-3d0ac889d515  opt_cvol_mcts100_debug
# 1  9b9922cb-6096-4490-b959-85f40a54a315  opt_cvol_mcts100_debug
# 2  1b60a1df-c1f0-4f9d-a055-7b2778a8b4d1  opt_cvol_mcts100_debug
# 3  453927b9-467e-4cca-8c63-47565cd51b4c  opt_cvol_mcts100_debug
# 4  51f42ee7-6287-4644-a16e-c1c242013cec  opt_cvol_mcts100_debug
#
#                         time  raw_reward  scaled_reward  \
# 0 2021-07-09 13:40:12.592983    0.355227            0.0
# 1 2021-07-09 13:40:13.503813    0.000000            1.0
# 2 2021-07-09 13:40:13.627252    0.051935            1.0
# 3 2021-07-09 13:40:16.262390    0.321801            1.0
# 4 2021-07-09 13:40:28.383165    0.304803            0.0
#
#                                    search_statistics  \
# 0  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 1  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 2  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 3  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 4  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
#
#                                 execution_statistics  time_hours
# 0  {'execution_time': {'get_next_actions': 0.0160...    0.000000
# 1  {'execution_time': {'get_next_actions': 0.0197...    0.000253
# 2  {'execution_time': {'get_next_actions': 0.0173...    0.000287
# 3  {'execution_time': {'get_next_actions': 0.0167...    0.001019
# 4  {'execution_time': {'get_next_actions': 0.0195...    0.004386
# Reading /projects/rlmolecule/jlaw/crystal_vol/opt_cvol_mcts100_debug/policy_checkpoints/log.csv
# /projects/rlmolecule/jlaw/crystal_vol/opt_cvol_mcts100_debug/viz/training-and-reward.svg
#                                                   digest                 hash  \
# 37688  4de8009af1dd428527a7be86463a6065f4ce887315b3e4...  8802997818691025470
# 80754  d5fdfe5f0cc71e07996872417bb2d639b80780ef9c8ae9...  8802997818691025470
# 94823  c1220764ef90087cba352cb25e3f8eb74a590d1ba71971...  7214899612293632996
# 80890  cb3138350dda964f0cc9b252cecf6b44c05b35dbd9359d...  7000003398653280363
# 83988  0433e150332f0c0d540d7b5c929ac2e446c304361cb257...  9118850087464527793
#
#                        run_id                       time   reward  \
# 37688  opt_cvol_mcts100_debug 2021-07-09 14:02:47.286220  0.95487
# 80754  opt_cvol_mcts100_debug 2021-07-09 14:24:29.741205  0.95487
# 94823  opt_cvol_mcts100_debug 2021-07-09 14:33:35.249387  0.95487
# 80890  opt_cvol_mcts100_debug 2021-07-09 14:24:35.524485  0.95487
# 83988  opt_cvol_mcts100_debug 2021-07-09 14:27:24.626318  0.95487
#
#                                                     data
# 37688  {'terminal': True, 'conducting_ion_vol': 5361....
# 80754  {'terminal': True, 'conducting_ion_vol': 5361....
# 94823  {'terminal': True, 'conducting_ion_vol': 5361....
# 80890  {'terminal': True, 'conducting_ion_vol': 5361....
# 83988  {'terminal': True, 'conducting_ion_vol': 5361....

# %%
df_rew.head()
# Out:
#                                                   digest                 hash  \
# 37688  4de8009af1dd428527a7be86463a6065f4ce887315b3e4...  8802997818691025470
# 80754  d5fdfe5f0cc71e07996872417bb2d639b80780ef9c8ae9...  8802997818691025470
# 94823  c1220764ef90087cba352cb25e3f8eb74a590d1ba71971...  7214899612293632996
# 80890  cb3138350dda964f0cc9b252cecf6b44c05b35dbd9359d...  7000003398653280363
# 83988  0433e150332f0c0d540d7b5c929ac2e446c304361cb257...  9118850087464527793
#
#                        run_id                       time   reward  \
# 37688  opt_cvol_mcts100_debug 2021-07-09 14:02:47.286220  0.95487
# 80754  opt_cvol_mcts100_debug 2021-07-09 14:24:29.741205  0.95487
# 94823  opt_cvol_mcts100_debug 2021-07-09 14:33:35.249387  0.95487
# 80890  opt_cvol_mcts100_debug 2021-07-09 14:24:35.524485  0.95487
# 83988  opt_cvol_mcts100_debug 2021-07-09 14:27:24.626318  0.95487
#
#                                                     data
# 37688  {'terminal': True, 'conducting_ion_vol': 5361....
# 80754  {'terminal': True, 'conducting_ion_vol': 5361....
# 94823  {'terminal': True, 'conducting_ion_vol': 5361....
# 80890  {'terminal': True, 'conducting_ion_vol': 5361....
# 83988  {'terminal': True, 'conducting_ion_vol': 5361....

# %%
len(df_rew)
# Out:
# 104517

# %%
df_rew['hash'].nunique()
# Out:
# 73054

# %%
df_rew[df_rew['reward'] > .9]['hash'].nunique()
# Out:
# 87

# %%
# initial results
for run_id in ["more_complex_debug", "include_fc_debug"]:
    df_rew = main_results(run_id, session)
# Out:
#                                      id              run_id  \
# 0  53deb0ff-b84d-4c5c-bb67-48f958867aa2  more_complex_debug
# 1  4306296a-7ac9-45e6-ad01-9dbe2a3cadcf  more_complex_debug
# 2  06ecb0af-18cc-433b-bf05-f01843b33a3c  more_complex_debug
# 3  3818753b-5e0e-4d28-829d-1de4f0d42197  more_complex_debug
# 4  94a1afaf-5dcc-4772-b72d-0bbc754c2ab6  more_complex_debug
#
#                         time  raw_reward  scaled_reward  \
# 0 2021-07-16 16:31:42.329489    0.048714            1.0
# 1 2021-07-16 16:31:42.382340    0.155115            1.0
# 2 2021-07-16 16:31:56.347513    0.688247            1.0
# 3 2021-07-16 16:31:56.513132    0.304761            1.0
# 4 2021-07-16 16:32:00.701230    0.232972            0.0
#
#                                    search_statistics  \
# 0  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 1  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 2  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 3  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 4  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
#
#                                 execution_statistics  time_hours
# 0  {'execution_time': {'get_next_actions': 0.0154...    0.000000
# 1  {'execution_time': {'get_next_actions': 0.0130...    0.000015
# 2  {'execution_time': {'get_next_actions': 0.0171...    0.003894
# 3  {'execution_time': {'get_next_actions': 0.0143...    0.003940
# 4  {'execution_time': {'get_next_actions': 0.0152...    0.005103
# Reading /projects/rlmolecule/jlaw/crystal_vol/more_complex_debug/policy_checkpoints/log.csv
# /projects/rlmolecule/jlaw/crystal_vol/more_complex_debug/viz/training-and-reward.svg
#                                                    digest  \
# 86079   cebf9d2702e974f0783565151984e78d14ccc3986fd8b8...
# 106332  d0a10c15429d7859a27612a79548d9b4801f474519f718...
# 76191   9d2a034e19969c577e5a60f8309539bce9d75dcc26d0a1...
# 102202  bbacdfabba4a882ff44a861535b918928a513ce6158a63...
# 93062   823ed19aa9a6df4392073ae4ba0ceb539814576a0300c5...
#
#                        hash              run_id                       time  \
# 86079   6365513629074300998  more_complex_debug 2021-07-16 17:18:44.224498
# 106332  2404015317369171244  more_complex_debug 2021-07-16 17:29:07.814993
# 76191   2404015317369171244  more_complex_debug 2021-07-16 17:14:05.294967
# 102202  4835184247465134124  more_complex_debug 2021-07-16 17:26:59.341756
# 93062   2404015317369171244  more_complex_debug 2021-07-16 17:22:20.415604
#
#           reward                                               data
# 86079   0.943824  {'terminal': True, 'conducting_ion_vol': 3222....
# 106332  0.943824  {'terminal': True, 'conducting_ion_vol': 3222....
# 76191   0.943824  {'terminal': True, 'conducting_ion_vol': 3222....
# 102202  0.943824  {'terminal': True, 'conducting_ion_vol': 3222....
# 93062   0.943824  {'terminal': True, 'conducting_ion_vol': 3222....
#                                      id            run_id  \
# 0  f9982839-aff6-4bb8-a822-405ac7e2f1a6  include_fc_debug
# 1  06f1921a-1ba6-4078-baf1-aaf19ac039bf  include_fc_debug
# 2  0f3da70b-dcba-48d3-acc5-c8b01676e21f  include_fc_debug
# 3  1605232f-9316-4978-ad0a-273342ed6059  include_fc_debug
# 4  cefdf10f-442e-484f-9c12-8154ba8b64e2  include_fc_debug
#
#                         time  raw_reward  scaled_reward  \
# 0 2021-07-16 17:31:53.975164         0.0            1.0
# 1 2021-07-16 17:31:54.833766         0.0            1.0
# 2 2021-07-16 17:31:54.993553         0.0            1.0
# 3 2021-07-16 17:31:56.032983         0.0            1.0
# 4 2021-07-16 17:31:58.736146         0.0            1.0
#
#                                    search_statistics  \
# 0  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 1  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 2  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 3  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 4  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
#
#                                 execution_statistics  time_hours
# 0  {'execution_time': {'get_next_actions': 0.0101...    0.000000
# 1  {'execution_time': {'get_next_actions': 0.0149...    0.000239
# 2  {'execution_time': {'get_next_actions': 0.0136...    0.000283
# 3  {'execution_time': {'get_next_actions': 0.0135...    0.000572
# 4  {'execution_time': {'get_next_actions': 0.0122...    0.001322
# Reading /projects/rlmolecule/jlaw/crystal_vol/include_fc_debug/policy_checkpoints/log.csv
# /projects/rlmolecule/jlaw/crystal_vol/include_fc_debug/viz/training-and-reward.svg
#                                                   digest                 hash  \
# 83700  fa3a9c60f8969a293c50b8ec3d901996b0aef2acee5d4a...  1756656333573177920
# 84132  6bef6b925309a9e6d8d0d3936a21173955cf01327db4be...   268487914446145353
# 56503  fb0c9c620ccc078e06358a79230f78fd6e8e15a633e8c1...  2410950498115942858
# 77455  70aea52ddaf0f0321edf485fd8e81bcf3d0a329c622975...  2410950498115942858
# 87706  0833a49f870b94ccbe0276c28cc4e6ed547532781c09be...  1756656333573177920
#
#                  run_id                       time    reward  \
# 83700  include_fc_debug 2021-07-16 18:20:45.573136  0.920894
# 84132  include_fc_debug 2021-07-16 18:21:04.145228  0.920894
# 56503  include_fc_debug 2021-07-16 18:05:19.434322  0.920894
# 77455  include_fc_debug 2021-07-16 18:17:21.978373  0.920894
# 87706  include_fc_debug 2021-07-16 18:23:26.975180  0.920894
#
#                                                     data
# 83700  {'terminal': True, 'conducting_ion_vol': 158.6...
# 84132  {'terminal': True, 'conducting_ion_vol': 158.6...
# 56503  {'terminal': True, 'conducting_ion_vol': 158.6...
# 77455  {'terminal': True, 'conducting_ion_vol': 158.6...
# 87706  {'terminal': True, 'conducting_ion_vol': 158.6...

# %%
run_id = "include_fc_debug_3"
df_rew = main_results(run_id, session)
df_rew.head(3)
# Out:
#                                      id              run_id  \
# 0  2e7ad6b0-80f6-4d50-958f-e53d87238ba3  include_fc_debug_3
# 1  e0465d2d-4e30-4826-b6de-47d6f01472ea  include_fc_debug_3
# 2  06e2c107-22b2-4bac-8a58-90ca50bd7fab  include_fc_debug_3
# 3  7f00891c-e3e8-44c1-9f2c-7b0917fb97ed  include_fc_debug_3
# 4  23f11438-617a-483d-ac07-450c0ef22b5c  include_fc_debug_3
#
#                         time  raw_reward  scaled_reward  \
# 0 2021-07-17 11:04:44.890123    0.000000            1.0
# 1 2021-07-17 11:04:46.924200    0.000000            0.0
# 2 2021-07-17 11:04:48.220963    0.000000            0.0
# 3 2021-07-17 11:04:53.024796    0.392534            0.0
# 4 2021-07-17 11:04:54.319946    0.000000            0.0
#
#                                    search_statistics  \
# 0  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 1  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 2  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 3  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
# 4  [[4f27ce5de30b5dbb727c1b2601211b1e7a7bc4b1ceb3...
#
#                                 execution_statistics  time_hours
# 0  {'execution_time': {'get_next_actions': 0.0121...    0.000000
# 1  {'execution_time': {'get_next_actions': 0.0130...    0.000565
# 2  {'execution_time': {'get_next_actions': 0.0122...    0.000925
# 3  {'execution_time': {'get_next_actions': 0.0160...    0.002260
# 4  {'execution_time': {'get_next_actions': 0.0107...    0.002619
# Reading /projects/rlmolecule/jlaw/crystal_vol/include_fc_debug_3/policy_checkpoints/log.csv
# /projects/rlmolecule/jlaw/crystal_vol/include_fc_debug_3/viz/training-and-reward.svg
#                                                   digest                 hash  \
# 51927  aca68bd617157f146de2f0396553596023ffc189bac75e...  5226064925282629680
# 3534   14dee084d38ec1a05ceee325f28e11dc3bc7b01d5852f9...  8667121723854735920
# 54401  ae4fc7d95c5024653710a2e7b093a2e48f2f31c93c9c57...  1527988293595884890
# 67246  e398532260a6f074a3166aef236cf7060c6f556d60a0fc...  3047976988927894889
# 24476  358c3d4ae26c5d9bf38ad42f3a97593f48407db831a56c...   586819620574928142
#
#                    run_id                       time    reward  \
# 51927  include_fc_debug_3 2021-07-17 11:36:13.329435  0.899258
# 3534   include_fc_debug_3 2021-07-17 11:06:34.765746  0.899258
# 54401  include_fc_debug_3 2021-07-17 11:37:24.953272  0.899258
# 67246  include_fc_debug_3 2021-07-17 11:44:54.788301  0.899258
# 24476  include_fc_debug_3 2021-07-17 11:19:13.895288  0.899258
#
#                                                     data
# 51927  {'terminal': True, 'conducting_ion_vol': 608.8...
# 3534   {'terminal': True, 'conducting_ion_vol': 608.8...
# 54401  {'terminal': True, 'conducting_ion_vol': 608.8...
# 67246  {'terminal': True, 'conducting_ion_vol': 608.8...
# 24476  {'terminal': True, 'conducting_ion_vol': 608.8...
#                                                   digest                 hash  \
# 51927  aca68bd617157f146de2f0396553596023ffc189bac75e...  5226064925282629680
# 3534   14dee084d38ec1a05ceee325f28e11dc3bc7b01d5852f9...  8667121723854735920
# 54401  ae4fc7d95c5024653710a2e7b093a2e48f2f31c93c9c57...  1527988293595884890
#
#                    run_id                       time    reward  \
# 51927  include_fc_debug_3 2021-07-17 11:36:13.329435  0.899258
# 3534   include_fc_debug_3 2021-07-17 11:06:34.765746  0.899258
# 54401  include_fc_debug_3 2021-07-17 11:37:24.953272  0.899258
#
#                                                     data
# 51927  {'terminal': True, 'conducting_ion_vol': 608.8...
# 3534   {'terminal': True, 'conducting_ion_vol': 608.8...
# 54401  {'terminal': True, 'conducting_ion_vol': 608.8...

# %%
top_rew = df_rew[df_rew['reward'] > 0.85]
print(len(top_rew))
# Out:
# 121

# %%
import pickle
import zlib

# %%
best_states = []
for i, (digest, hash_str, run_id, time, rew, data) in top_rew.iterrows():
#     if digest in df_state['digest']:
    states = get_state_for_rew(digest, df_state)
    for state_str in states['state']:
#         state_str = get_state_for_rew(digest, df_state)['state'].values[0]
# #     if hash_str in df_state['hash']:
# #         state_str = df_state[df_state['hash'] == hash_str]['state'].values[0]
        crystal = pickle.loads(zlib.decompress(state_str))
        best_states.append(crystal)
len(best_states)
# Out:
# 0

# %%
best_decorations = set([str(c) + '|1' if '|1' not in str(c) else str(c) for c in best_states])
len(best_decorations)
# Out:
# 0

# %%
from examples.crystal_volume import optimize_crystal_volume as ocv
from rlmolecule.crystal.crystal_state import CrystalState
from tqdm.notebook import tqdm
# Out:
# INFO:examples.crystal_volume.optimize_crystal_volume:reading ../../rlmolecule/crystal/inputs/icsd_prototypes.json.gz
# INFO:examples.crystal_volume.optimize_crystal_volume:	4170 structures read

# %%
def write_decorated_structure(decorated_str, out_dir):
    # Now create the decoration of this composition onto this prototype structure
    # the 'action_node' string has the following format at this point:
    # comp_type|prototype_structure|decoration_idx
    # we just need 'comp_type|prototype_structure' to get the icsd structure
    composition = decorated_str.split('|')[0]
    structure_key = '|'.join(decorated_str.split('|')[1:-1])
    icsd_prototype = ocv.structures[structure_key]
    decoration_idx = int(decorated_str.split('|')[-1]) - 1
    print(decorated_str, composition, structure_key)
    try:
        decorated_structure, comp = CrystalState.decorate_prototype_structure(
            icsd_prototype, composition, decoration_idx=decoration_idx)
        #decorations[descriptor] = decorated_structure.as_dict()
    except AssertionError as e:
        print(f"AssertionError: {e}")
        return
        #volume_stats[descriptor] = (-1, -1, 0, comp_type)
        #return 0.0, {'terminal': True, 'state_repr': repr(state)}

    # Compute the volume of the conducting ions.
    conducting_ion_vol, total_vol = ocv.compute_structure_vol(decorated_structure)
    frac_conducting_ion_vol = conducting_ion_vol / total_vol if total_vol != 0 else 0
#     print(conducting_ion_vol, total_vol, frac_conducting_ion_vol)
    out_file = f"{out_dir}/POSCAR_{decorated_str.replace('|','-')}"
    print(f"writing {out_file}")
    decorated_structure.to(filename=out_file)
    
    # also write the original poscar file for reference
    out_file2 = f"{out_dir}/icsd_structures/{decorated_str.split('|')[-2]}"
    os.makedirs(os.path.dirname(out_file2), exist_ok=True)
    if not os.path.isfile(out_file2):
        icsd_prototype.to(filename=out_file2)
        
    return [conducting_ion_vol, total_vol, frac_conducting_ion_vol]

# %%
# now write each of these to a file
out_dir = f"outputs/{run_id}-0_85"
os.makedirs(out_dir, exist_ok=True)
volume_stats = {}
for decorated_str in tqdm(best_decorations):
    vol_stats = write_decorated_structure(decorated_str, out_dir)
    volume_stats[decorated_str] = [decorated_str.split('|')[-2]] + vol_stats
# Out:
#   0%|          | 0/65 [00:00<?, ?it/s]
# Na2S1|_1_2|orthorhombic|POSCAR_sg70_icsd_248069|1 Na2S1 _1_2|orthorhombic|POSCAR_sg70_icsd_248069
# writing outputs/more_complex_debug-0_85/POSCAR_Na2S1-_1_2-orthorhombic-POSCAR_sg70_icsd_248069-1
# Na2O1|_1_2|cubic|POSCAR_sg227_icsd_170476|1 Na2O1 _1_2|cubic|POSCAR_sg227_icsd_170476
# writing outputs/more_complex_debug-0_85/POSCAR_Na2O1-_1_2-cubic-POSCAR_sg227_icsd_170476-1
# K2S1|_1_2|cubic|POSCAR_sg230_icsd_170477|1 K2S1 _1_2|cubic|POSCAR_sg230_icsd_170477
# writing outputs/more_complex_debug-0_85/POSCAR_K2S1-_1_2-cubic-POSCAR_sg230_icsd_170477-1
# Li2S1|_1_2|cubic|POSCAR_sg227_icsd_170476|1 Li2S1 _1_2|cubic|POSCAR_sg227_icsd_170476
# writing outputs/more_complex_debug-0_85/POSCAR_Li2S1-_1_2-cubic-POSCAR_sg227_icsd_170476-1
# K3P1|_1_3|monoclinic|POSCAR_sg14_icsd_413919|1 K3P1 _1_3|monoclinic|POSCAR_sg14_icsd_413919
# writing outputs/more_complex_debug-0_85/POSCAR_K3P1-_1_3-monoclinic-POSCAR_sg14_icsd_413919-1
# Na2S1|_1_2|cubic|POSCAR_sg217_icsd_173559|1 Na2S1 _1_2|cubic|POSCAR_sg217_icsd_173559
# writing outputs/more_complex_debug-0_85/POSCAR_Na2S1-_1_2-cubic-POSCAR_sg217_icsd_173559-1
# K2O1|_1_2|hexagonal|POSCAR_sg194_icsd_170481|1 K2O1 _1_2|hexagonal|POSCAR_sg194_icsd_170481
# writing outputs/more_complex_debug-0_85/POSCAR_K2O1-_1_2-hexagonal-POSCAR_sg194_icsd_170481-1
# Li2S1|_1_2|cubic|POSCAR_sg230_icsd_170477|1 Li2S1 _1_2|cubic|POSCAR_sg230_icsd_170477
# writing outputs/more_complex_debug-0_85/POSCAR_Li2S1-_1_2-cubic-POSCAR_sg230_icsd_170477-1
# Na2S1|_1_2|orthorhombic|POSCAR_sg63_icsd_093779|1 Na2S1 _1_2|orthorhombic|POSCAR_sg63_icsd_093779
# writing outputs/more_complex_debug-0_85/POSCAR_Na2S1-_1_2-orthorhombic-POSCAR_sg63_icsd_093779-1
# Li2O1|_1_2|monoclinic|POSCAR_sg12_icsd_089837|1 Li2O1 _1_2|monoclinic|POSCAR_sg12_icsd_089837
# writing outputs/more_complex_debug-0_85/POSCAR_Li2O1-_1_2-monoclinic-POSCAR_sg12_icsd_089837-1
# K2S1|_1_2|cubic|POSCAR_sg227_icsd_170476|1 K2S1 _1_2|cubic|POSCAR_sg227_icsd_170476
# writing outputs/more_complex_debug-0_85/POSCAR_K2S1-_1_2-cubic-POSCAR_sg227_icsd_170476-1
# Li3P1|_1_3|monoclinic|POSCAR_sg14_icsd_413919|1 Li3P1 _1_3|monoclinic|POSCAR_sg14_icsd_413919
# writing outputs/more_complex_debug-0_85/POSCAR_Li3P1-_1_3-monoclinic-POSCAR_sg14_icsd_413919-1
# K2O1|_1_2|hexagonal|POSCAR_sg191_icsd_089700|1 K2O1 _1_2|hexagonal|POSCAR_sg191_icsd_089700
# writing outputs/more_complex_debug-0_85/POSCAR_K2O1-_1_2-hexagonal-POSCAR_sg191_icsd_089700-1
# Na2O1|_1_2|cubic|POSCAR_sg227_icsd_055488|1 Na2O1 _1_2|cubic|POSCAR_sg227_icsd_055488
# writing outputs/more_complex_debug-0_85/POSCAR_Na2O1-_1_2-cubic-POSCAR_sg227_icsd_055488-1
# K2O1|_1_2|cubic|POSCAR_sg227_icsd_170476|1 K2O1 _1_2|cubic|POSCAR_sg227_icsd_170476
# writing outputs/more_complex_debug-0_85/POSCAR_K2O1-_1_2-cubic-POSCAR_sg227_icsd_170476-1
# Na2O1|_1_2|cubic|POSCAR_sg229_icsd_170479|1 Na2O1 _1_2|cubic|POSCAR_sg229_icsd_170479
# writing outputs/more_complex_debug-0_85/POSCAR_Na2O1-_1_2-cubic-POSCAR_sg229_icsd_170479-1
# Li2O1|_1_2|cubic|POSCAR_sg229_icsd_170475|1 Li2O1 _1_2|cubic|POSCAR_sg229_icsd_170475
# writing outputs/more_complex_debug-0_85/POSCAR_Li2O1-_1_2-cubic-POSCAR_sg229_icsd_170475-1
# K2O1|_1_2|tetragonal|POSCAR_sg127_icsd_171737|1 K2O1 _1_2|tetragonal|POSCAR_sg127_icsd_171737
# writing outputs/more_complex_debug-0_85/POSCAR_K2O1-_1_2-tetragonal-POSCAR_sg127_icsd_171737-1
# Li2S1|_1_2|hexagonal|POSCAR_sg187_icsd_076577|1 Li2S1 _1_2|hexagonal|POSCAR_sg187_icsd_076577
# writing outputs/more_complex_debug-0_85/POSCAR_Li2S1-_1_2-hexagonal-POSCAR_sg187_icsd_076577-1
# Na2O1|_1_2|cubic|POSCAR_sg229_icsd_170475|1 Na2O1 _1_2|cubic|POSCAR_sg229_icsd_170475
# writing outputs/more_complex_debug-0_85/POSCAR_Na2O1-_1_2-cubic-POSCAR_sg229_icsd_170475-1
# Li2S1|_1_2|hexagonal|POSCAR_sg194_icsd_170481|1 Li2S1 _1_2|hexagonal|POSCAR_sg194_icsd_170481
# writing outputs/more_complex_debug-0_85/POSCAR_Li2S1-_1_2-hexagonal-POSCAR_sg194_icsd_170481-1
# Na2O1|_1_2|cubic|POSCAR_sg217_icsd_173559|1 Na2O1 _1_2|cubic|POSCAR_sg217_icsd_173559
# writing outputs/more_complex_debug-0_85/POSCAR_Na2O1-_1_2-cubic-POSCAR_sg217_icsd_173559-1
# Na2S1|_1_2|hexagonal|POSCAR_sg194_icsd_170481|1 Na2S1 _1_2|hexagonal|POSCAR_sg194_icsd_170481
# writing outputs/more_complex_debug-0_85/POSCAR_Na2S1-_1_2-hexagonal-POSCAR_sg194_icsd_170481-1
# K2O1|_1_2|cubic|POSCAR_sg227_icsd_055488|1 K2O1 _1_2|cubic|POSCAR_sg227_icsd_055488
# writing outputs/more_complex_debug-0_85/POSCAR_K2O1-_1_2-cubic-POSCAR_sg227_icsd_055488-1
# K2O1|_1_2|orthorhombic|POSCAR_sg70_icsd_248069|1 K2O1 _1_2|orthorhombic|POSCAR_sg70_icsd_248069
# writing outputs/more_complex_debug-0_85/POSCAR_K2O1-_1_2-orthorhombic-POSCAR_sg70_icsd_248069-1
# K2O1|_1_2|cubic|POSCAR_sg229_icsd_170475|1 K2O1 _1_2|cubic|POSCAR_sg229_icsd_170475
# writing outputs/more_complex_debug-0_85/POSCAR_K2O1-_1_2-cubic-POSCAR_sg229_icsd_170475-1
# Na2O1|_1_2|hexagonal|POSCAR_sg171_icsd_171734|1 Na2O1 _1_2|hexagonal|POSCAR_sg171_icsd_171734
# writing outputs/more_complex_debug-0_85/POSCAR_Na2O1-_1_2-hexagonal-POSCAR_sg171_icsd_171734-1
# Na2S1|_1_2|hexagonal|POSCAR_sg171_icsd_171734|1 Na2S1 _1_2|hexagonal|POSCAR_sg171_icsd_171734
# writing outputs/more_complex_debug-0_85/POSCAR_Na2S1-_1_2-hexagonal-POSCAR_sg171_icsd_171734-1
# Li2O1|_1_2|cubic|POSCAR_sg227_icsd_170476|1 Li2O1 _1_2|cubic|POSCAR_sg227_icsd_170476
# writing outputs/more_complex_debug-0_85/POSCAR_Li2O1-_1_2-cubic-POSCAR_sg227_icsd_170476-1
# Li2O1|_1_2|cubic|POSCAR_sg230_icsd_170477|1 Li2O1 _1_2|cubic|POSCAR_sg230_icsd_170477
# writing outputs/more_complex_debug-0_85/POSCAR_Li2O1-_1_2-cubic-POSCAR_sg230_icsd_170477-1
# Li2S1|_1_2|hexagonal|POSCAR_sg171_icsd_171734|1 Li2S1 _1_2|hexagonal|POSCAR_sg171_icsd_171734
# writing outputs/more_complex_debug-0_85/POSCAR_Li2S1-_1_2-hexagonal-POSCAR_sg171_icsd_171734-1
# Na2S1|_1_2|cubic|POSCAR_sg230_icsd_170477|1 Na2S1 _1_2|cubic|POSCAR_sg230_icsd_170477
# writing outputs/more_complex_debug-0_85/POSCAR_Na2S1-_1_2-cubic-POSCAR_sg230_icsd_170477-1
# Li2O1|_1_2|cubic|POSCAR_sg217_icsd_173559|1 Li2O1 _1_2|cubic|POSCAR_sg217_icsd_173559
# writing outputs/more_complex_debug-0_85/POSCAR_Li2O1-_1_2-cubic-POSCAR_sg217_icsd_173559-1
# K2O1|_1_2|monoclinic|POSCAR_sg12_icsd_089837|1 K2O1 _1_2|monoclinic|POSCAR_sg12_icsd_089837
# writing outputs/more_complex_debug-0_85/POSCAR_K2O1-_1_2-monoclinic-POSCAR_sg12_icsd_089837-1
# Na3P1|_1_3|monoclinic|POSCAR_sg14_icsd_413919|1 Na3P1 _1_3|monoclinic|POSCAR_sg14_icsd_413919
# writing outputs/more_complex_debug-0_85/POSCAR_Na3P1-_1_3-monoclinic-POSCAR_sg14_icsd_413919-1
# Na2O1|_1_2|hexagonal|POSCAR_sg191_icsd_089700|1 Na2O1 _1_2|hexagonal|POSCAR_sg191_icsd_089700
# writing outputs/more_complex_debug-0_85/POSCAR_Na2O1-_1_2-hexagonal-POSCAR_sg191_icsd_089700-1
# Na2S1|_1_2|monoclinic|POSCAR_sg12_icsd_089837|1 Na2S1 _1_2|monoclinic|POSCAR_sg12_icsd_089837
# writing outputs/more_complex_debug-0_85/POSCAR_Na2S1-_1_2-monoclinic-POSCAR_sg12_icsd_089837-1
# Na2S1|_1_2|cubic|POSCAR_sg227_icsd_170476|1 Na2S1 _1_2|cubic|POSCAR_sg227_icsd_170476
# writing outputs/more_complex_debug-0_85/POSCAR_Na2S1-_1_2-cubic-POSCAR_sg227_icsd_170476-1
# Na3N1|_1_3|monoclinic|POSCAR_sg14_icsd_413919|1 Na3N1 _1_3|monoclinic|POSCAR_sg14_icsd_413919
# writing outputs/more_complex_debug-0_85/POSCAR_Na3N1-_1_3-monoclinic-POSCAR_sg14_icsd_413919-1
# Na2S1|_1_2|cubic|POSCAR_sg227_icsd_055488|1 Na2S1 _1_2|cubic|POSCAR_sg227_icsd_055488
# writing outputs/more_complex_debug-0_85/POSCAR_Na2S1-_1_2-cubic-POSCAR_sg227_icsd_055488-1
# Li2O1|_1_2|hexagonal|POSCAR_sg191_icsd_089700|1 Li2O1 _1_2|hexagonal|POSCAR_sg191_icsd_089700
# writing outputs/more_complex_debug-0_85/POSCAR_Li2O1-_1_2-hexagonal-POSCAR_sg191_icsd_089700-1
# K2S1|_1_2|hexagonal|POSCAR_sg194_icsd_170481|1 K2S1 _1_2|hexagonal|POSCAR_sg194_icsd_170481
# writing outputs/more_complex_debug-0_85/POSCAR_K2S1-_1_2-hexagonal-POSCAR_sg194_icsd_170481-1
# Li2O1|_1_2|hexagonal|POSCAR_sg194_icsd_170481|1 Li2O1 _1_2|hexagonal|POSCAR_sg194_icsd_170481
# writing outputs/more_complex_debug-0_85/POSCAR_Li2O1-_1_2-hexagonal-POSCAR_sg194_icsd_170481-1
# K2O1|_1_2|cubic|POSCAR_sg230_icsd_170477|1 K2O1 _1_2|cubic|POSCAR_sg230_icsd_170477
# writing outputs/more_complex_debug-0_85/POSCAR_K2O1-_1_2-cubic-POSCAR_sg230_icsd_170477-1
# K2S1|_1_2|cubic|POSCAR_sg217_icsd_173559|1 K2S1 _1_2|cubic|POSCAR_sg217_icsd_173559
# writing outputs/more_complex_debug-0_85/POSCAR_K2S1-_1_2-cubic-POSCAR_sg217_icsd_173559-1
# Li2S1|_1_2|hexagonal|POSCAR_sg191_icsd_089700|1 Li2S1 _1_2|hexagonal|POSCAR_sg191_icsd_089700
# writing outputs/more_complex_debug-0_85/POSCAR_Li2S1-_1_2-hexagonal-POSCAR_sg191_icsd_089700-1
# Li2S1|_1_2|monoclinic|POSCAR_sg12_icsd_089837|1 Li2S1 _1_2|monoclinic|POSCAR_sg12_icsd_089837
# writing outputs/more_complex_debug-0_85/POSCAR_Li2S1-_1_2-monoclinic-POSCAR_sg12_icsd_089837-1
# K2O1|_1_2|hexagonal|POSCAR_sg171_icsd_171734|1 K2O1 _1_2|hexagonal|POSCAR_sg171_icsd_171734
# writing outputs/more_complex_debug-0_85/POSCAR_K2O1-_1_2-hexagonal-POSCAR_sg171_icsd_171734-1
# Li3N1|_1_3|monoclinic|POSCAR_sg14_icsd_413919|1 Li3N1 _1_3|monoclinic|POSCAR_sg14_icsd_413919
# writing outputs/more_complex_debug-0_85/POSCAR_Li3N1-_1_3-monoclinic-POSCAR_sg14_icsd_413919-1
# K2O1|_1_2|cubic|POSCAR_sg229_icsd_170479|1 K2O1 _1_2|cubic|POSCAR_sg229_icsd_170479
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-ccf76c371786> in <module>
#       4 volume_stats = {}
#       5 for decorated_str in tqdm(best_decorations):
# ----> 6     vol_stats = write_decorated_structure(decorated_str, out_dir)
#       7     volume_stats[decorated_str] = [decorated_str.split('|')[-2]] + vol_stats
#
# <ipython-input-31-98bc9caed0d0> in write_decorated_structure(decorated_str, out_dir)
#      20
#      21     # Compute the volume of the conducting ions.
# ---> 22     conducting_ion_vol, total_vol = ocv.compute_structure_vol(decorated_structure)
#      23     frac_conducting_ion_vol = conducting_ion_vol / total_vol if total_vol != 0 else 0
#      24 #     print(conducting_ion_vol, total_vol, frac_conducting_ion_vol)
#
# ~/projects/arpa-e/crystals/rlmolecule/examples/crystal_volume/../../examples/crystal_volume/optimize_crystal_volume.py in compute_structure_vol(structure, state)
#      52     for nn in [nn13]:
#      53         try:
# ---> 54             voronoi_stats = nn.get_all_voronoi_polyhedra(structure)
#      55             break
#      56         # this function often fails for large or spaced out structures
#
# ~/.conda/envs/crystals/lib/python3.8/site-packages/pymatgen/analysis/local_env.py in get_all_voronoi_polyhedra(self, structure)
#     782         # Get the non-duplicates (using the site indices for numerical stability)
#     783         indices = np.array(indices, dtype=np.int_)
# --> 784         indices, uniq_inds = np.unique(indices, return_index=True, axis=0)
#     785         sites = [sites[i] for i in uniq_inds]
#     786
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~/.conda/envs/crystals/lib/python3.8/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     312         return uniq
#     313
# --> 314     output = _unique1d(consolidated, return_index,
#     315                        return_inverse, return_counts)
#     316     output = (reshape_uniq(output[0]),) + output[1:]
#
# ~/.conda/envs/crystals/lib/python3.8/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     328
#     329     if optional_indices:
# --> 330         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     331         aux = ar[perm]
#     332     else:
#
# KeyboardInterrupt:

# %%
df_vol_stats = pd.DataFrame(volume_stats).T
df_vol_stats.columns = ['icsd_prototype', 'conducting_ion_vol', 'total_vol', 'fraction']
df_vol_stats.head()

# %%
out_file = f"{out_dir}/volume_stats.tsv"
df_vol_stats.to_csv(out_file, sep='\t')
